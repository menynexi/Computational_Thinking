# %% [markdown]
# ### Computational Thinking
# I am a computer science student who has taken upper division classes and going back to the basics at first felt really slow. I had a lot of fun doing the projects in this class as I could just stretch out my creative mind and do the most absurd and goofy projects possible. Something upper division classes were not made for. Things started to get more interesting when the class introduced looking at data and analyzing it with pandas, numpy, and matplotlib libraries that were very new to me. SOOOO.. as any great programer “I failed fast and failed hard” my first project with data visualization was a mess of graphs, bugs, concatenation issues, more bugs 0-0 and questions with no real direction or concrete analysis but, It did teach me what could work and what did not work for specific visualization problems. Going into this project I asked a very important question. What do I want to analyze in this dataset? This gave me direction and with my previous knowledge I set out on an adventure to see what generation was the most well rounded from generation 1 through 6.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # POKEMON - A Journey about generations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# "Hello there! Welcome to the world of Pokémon! My name is Oak! People call me the Pokémon Prof! This world is inhabited by creatures called Pokémon! For some people, Pokémon are pets. Other use them for fights. Myself… I study Pokémon as a profession alongside my assistant Many we want to see which generation of pokemon are the stringest. Using the dataset derived from *"Pokemon with stats" by Alberto Barradas. This dataset *contains 800 pokemons from 6 generations all in one pokedex**. The data set is compiled of 800 Pokémon and includes their Number, Name, Type 1, Type 2, Generation and basic stats such as: HP, Attack, Defense, Special Attack, Special Defense, and Speed.
#
# Without further to do our very own Pokémon legend is about to unfold! A world of dreams and adventures with Pokémon awaits! Let's go!"

# %% [markdown]
# # What Questions do we want to ask
# <ol>
#   <li>How many Pokemon are in each Generation ?</li>
#   <li>Which generation has the over all higher <b>HP, Attack, Defense, Special Attack, Special Defence, and speed</b>? <br>(this can be considered multiple sub questions)</li>
#   <li>Which generation is the most rounded of them all</li>
# </ol>
#
# I will try and answer all of these question while analyzing and pointing out some flaws in the dataset
#
# Note: that when I say rounded I mean taking the sum of all the stats of each generation; and seeing which one has a better average over all

# %% [markdown]
# ###------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###THE CODE

# %% [markdown]
# WARNING : this notebook won't run unless the .ipynb file and the .csv file are in the same folder. if you are having problems with the directory copy the absolute path of the location of your pokemon dataset

# %%
#step one import libraries
#facilitates data science
import pandas as pd

#facilitates math
import numpy as np

# New Library!!
import matplotlib.pyplot as plt

#this will display graphs inline (in this notebook)
# %matplotlib inline

#specify how large to show figures (length, width)
plt.rcParams["figure.figsize"] = (8, 6)

# %%
#step two read the dataset and assign it to a variable 
#I used an absolute path to make it easier for the library to detet where the dataset was but is optional 
#note please make sure the directory is the same as mine when testing or edit to match the directory in which the dataset is located
pokemon = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pokemon_viz.csv")
df = pd.DataFrame(data = pokemon)

# %%
#check to see if pokemon was read correctly with .head()
#head will override, so I use comments to make sure I'm running the one I want to see. 
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Unnamed: 13  Unnamed: 14  \
# 0       65       65     45           1      False          NaN          NaN
# 1       80       80     60           1      False          NaN          NaN
# 2      100      100     80           1      False          NaN          NaN
# 3      122      120     80           1      False          NaN          NaN
# 4       60       50     65           1      False          NaN          NaN
#
#    Unnamed: 15
# 0        194.0
# 1         10.0
# 2          NaN
# ...

# %% [markdown]
# Here are where I noticed Some minor problems with the dataset, pokemon by generation are classified by its original generation. For example VenusaurMega Venusaur is part of the MEGA evolutions which came from Generation 6 but it is classified as Generation 1 because Venusaur first apperaed in Gen 1. So the question now becomes *which of Generation is the strongest based on their original pokemon.* and according to the dataset being used

# %% [markdown]
# ### QUESTION 1: How many Pokemon are in each Generation ?

# %%
pokemon_gen = pokemon["Generation"].value_counts()

df['Generation'].value_counts(ascending=True).plot(kind= 'barh', width = 0.75);
plt.ylabel("Number of pokemon", labelpad=20, fontsize = 14)
plt.xlabel("Generation", labelpad=20, fontsize = 14)
plt.title("Number of Pokémon per Generation", fontsize = 18);

# %%
print(pokemon_gen)
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %% [markdown]
# ### QUESTION 2: Which generation has the over all higher HP, Attack, Defense, Special Attack, Special Defence, and speed?
# (this can be considered multiple sub questions)

# %% [markdown]
# ###Which generation has a higher average HP?

# %%
gen =  pokemon.groupby('Generation')['HP'].mean()
plt.title("Average Pokémon HP per Generation", fontsize = 18);
plt.xlabel("Generation", labelpad=20, fontsize = 14)
plt.ylabel("HP", labelpad=20, fontsize = 14)
gen.plot()

# %% [markdown]
# Answer : Generation 4 has the highest HP average out off all the Generations

# %% [markdown]
# ###Which generation has a higher average Attack?

# %%
gen =  pokemon.groupby('Generation')['Attack'].mean()
plt.title("Average Pokémon Attack per Generation", fontsize = 18);
plt.xlabel("Generation", labelpad=20, fontsize = 14)
plt.ylabel("Attack", labelpad=20, fontsize = 14)
gen.plot()

# %% [markdown]
# Answer : Generation 4 has the highest Attack average out off all the Generations

# %% [markdown]
# ###Which generation has a higher average Defense?

# %%
gen =  pokemon.groupby('Generation')['Defense'].mean()
plt.title("Average Pokémon Defense per Generation", fontsize = 18);
plt.xlabel("Generation", labelpad=20, fontsize = 14)
plt.ylabel("Defense", labelpad=20, fontsize = 14)
gen.plot()

# %% [markdown]
# Answer : Generation 4 has the highest Defense average out off all the Generations

# %% [markdown]
# ###Which generation has a higher average Sp.Attack?

# %%
gen =  pokemon.groupby('Generation')['Sp. Atk'].mean()
plt.title("Average Pokémon Sp. Atk per Generation", fontsize = 18);
plt.xlabel("Generation", labelpad=20, fontsize = 14)
plt.ylabel("Sp. Atk", labelpad=20, fontsize = 14)
gen.plot()

# %% [markdown]
# Answer : Generation 4 has the highest Sp. Atk average out off all the Generations

# %% [markdown]
# ###Which generation has a higher average Sp. Defense?

# %%
gen =  pokemon.groupby('Generation')['Sp. Def'].mean()
plt.title("Average Pokémon Sp. Atk per Generation", fontsize = 18);
plt.xlabel("Generation", labelpad=20, fontsize = 14)
plt.ylabel("Sp. Def", labelpad=20, fontsize = 14)
gen.plot()

# %% [markdown]
# Answer : Generation 4 has the highest Sp. Atk average out off all the Generations

# %% [markdown]
# ###Which generation has a higher average Speed?

# %%
gen =  pokemon.groupby('Generation')['Speed'].mean()
plt.title("Average Pokémon Speed per Generation", fontsize = 18);
plt.xlabel("Generation", labelpad=20, fontsize = 14)
plt.ylabel("Speed", labelpad=20, fontsize = 14)
gen.plot()

# %% [markdown]
# Answer : Generation 1 has the highest Speed average out off all the Generations

# %% [markdown]
# ###QUESTION 3: Which generation is the most rounded of them all

# %%
gen =  pokemon.groupby('Generation')['Total'].mean()
plt.title("Average Pokémon Total per Generation", fontsize = 18);
plt.xlabel("Generation", labelpad=20, fontsize = 14)
plt.ylabel("Total", labelpad=20, fontsize = 14)
gen.plot()

# %% [markdown]
# Answer: We can clearly see that over all generation 4 has the highest mean of total stats.

# %% [markdown]
# ###Conclusion++

# %% [markdown]
# Over all this came to me as a surpise because I started with generation 4 as a kid but never tought it was the strongest class. Before analyzing the data I believed that Generation 1 had the strongest monsters of all generations. I did learn that if we would have calculated based on the count Generation 1 would have been the strongest mainly for the large amount of pokemon it has. **So I tought what if they all had the same number of pokemon which generation would be the strongest?**

# %% [markdown]
# ###QUESTION 4: If every generation all had the same number of pokemon which generation would be the strongest overall based on total stats?

# %% [markdown]
# First I will divide the dataset into generations so we can isolate them into their own list. The reason why we will isolate them is to get the strongest Total stats from every pokemon

# %%
# we issolate them by ranging them from were every generation starts and ends
gen1pokemon = pokemon[:166]
gen2pokemon = pokemon[166:272]
gen3pokemon = pokemon[272:432]
gen4pokemon = pokemon[432:553]
gen5pokemon = pokemon[553:718]
gen6pokemon = pokemon[718::]

# %% [markdown]
# Then I will Issolate them even further and get the first 82 pokemon who have the highest over all total stats. The reason why I chose 82 was because that is the smallest number of pokemon in a generation.

# %%
gen1 = gen1pokemon.sort_values(by = "Total", ascending = False)[0:82]
gen2 = gen2pokemon.sort_values(by = "Total", ascending = False)[0:82]
gen3 = gen3pokemon.sort_values(by = "Total", ascending = False)[0:82]
gen4 = gen4pokemon.sort_values(by = "Total", ascending = False)[0:82]
gen5 = gen5pokemon.sort_values(by = "Total", ascending = False)[0:82]
gen6 = gen6pokemon.sort_values(by = "Total", ascending = False)[0:82]

# %% [markdown]
# Then I will calculate the over all average of each generation beased on their total stats and organize them into a single list so that I can effectively plot them in a single figure.

# %%
gen1total = gen1["Total"].mean()
gen2total = gen2["Total"].mean()
gen3total = gen3["Total"].mean()
gen4total = gen4["Total"].mean()
gen5total = gen5["Total"].mean()
gen6total = gen6["Total"].mean()

gennumber= [1,2,3,4,5,6]
genTotal = [gen1total,gen2total,gen3total,gen4total,gen5total,gen6total]

plt.bar(gennumber, genTotal)

plt.title("Average Pokémon Total stats per Generation", fontsize = 18);
plt.xlabel("Generation", labelpad=20, fontsize = 14)
plt.ylabel("Total", labelpad=20, fontsize = 14)
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# Answer: As you can see isolating each generation with the same number of pokemon did make a diffrence over all in which generation is the strongest. If every generation all had the same number of pokemon; Generation 3 would have the highest total stats over all.

# %% [markdown]
# ##This project was really fun and I am proud of the questions I came up with. Our journey of data exploration ends here but, <br>
# ####This project will be posted on my gitHub alongside my other projects for this class.(Shameless plug) Feel free to check them out if you want<br><br> "Catch you on the flip side" - MENY
